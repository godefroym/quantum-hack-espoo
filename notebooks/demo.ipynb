# %% [markdown]
# # Quantum Systemic Stress Scenario Discovery
#
# Minimal notebook placeholder for running the MVP pipeline interactively.

# %%
from systemic_risk.data import make_synthetic_system
from systemic_risk.generators import BernoulliGenerator, GaussianCopulaGenerator, StudentTCopulaGenerator, EntangledPQCGenerator
from systemic_risk.evaluation import EvaluationHarness

spec = make_synthetic_system(n=16, seed=7)
generators = [BernoulliGenerator(), GaussianCopulaGenerator(), StudentTCopulaGenerator(), EntangledPQCGenerator()]
harness = EvaluationHarness(spec, n_samples=1000, seed=2026)
harness.to_frame(harness.run(generators))
